# %%
import pandas as pd
from scipy import optimize
from scipy.optimize import curve_fit
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from collections import Counter
from collections import defaultdict
import matplotlib.font_manager as fm
import os
import powerlaw
from powerlaw import plot_pdf, Fit, pdf,ccdf

# %%
file_path='D:Fig_S8/degree/'
files=os.listdir(file_path)
files.sort(key=lambda x:int(x.split('/')[-1].split('_')[0]))

# %%
#Fig.S8
n=1
fig = plt.figure(figsize=(16, 22))
for i in range(2,len(files)):
    time=files[i].replace('.csv','')
    position=file_path+files[i]
    df=pd.read_csv(position,encoding='gbk')

    degree=list(df['degree'])
    d=degree[0:degree.index(0)]
    arr=Counter(d)
    dg=list(arr.keys())
    degree=np.array(dg)
    N=list(arr.values())
    p_n=[item/sum(N) for item in N] 
    def func(x,w,a):
        return w*x**(-a)
    np.array(degree)
    np.array(p_n)
    popt,pcov=curve_fit(func,degree,p_n,maxfev=500000)
    print(popt)
    y_pred=func(degree,*popt)
    ax = fig.add_subplot(6,3,n)
    plt.scatter(degree,p_n, c='green',label='degree data')
    plt.plot(degree,y_pred,c='red',label='power law fit')
    
 
    plt.xticks(fontsize=13)
    plt.yticks(fontsize=13) 
    if n==1 or n==4 or n==7 or n==10 or n==13 or n==16:
        plt.ylabel('P(k)',fontsize=13)
    if n>=16:
        plt.xlabel('k',fontsize=13)
    
    plt.title(time,fontsize=13)
    Regression = sum(y_pred - np.mean(p_n)**2) 
    Residual  = sum((p_n - y_pred)**2)    
    total = sum((p_n-np.mean(p_n))**2) 
    if total == 0:
        R_square=0
    else:
        R_square  = 1-Residual / total 
    print('R_square:',R_square)
    a=popt[0]
    b=popt[1]
    c=R_square
    if i<=3:
        d=50
        e1=0.032
        e2=0.02
    elif i<=5:
        d=70
        e1=0.032
        e2=0.022
    elif i==6:
        d=120
        e1=0.018
        e2=0.008
    elif i<=8:
        d=250
        e1=0.015
        e2=0.008
    elif i<=10:
        d=400
        e1=0.015
        e2=0.008
    else:
        d=400
        e1=0.015
        e2=0.008
        
    if i==2:
        plt.text(d,e1,r'$P(k)=0.08k^{-0.51}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.48$',fontsize=14)
    elif i==3:
        plt.text(d,e1,r'$P(k)=0.09k^{-0.55}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.60$',fontsize=14)
    elif i==4:
        plt.text(d,e1,r'$P(k)=0.08k^{-0.55}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.61$',fontsize=14)
    elif i==5:
        plt.text(d,e1,r'$P(k)=0.08k^{-0.55}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.62$',fontsize=14)
    elif i==6:
        plt.text(d,e1,r'$P(k)=0.05k^{-0.55}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.71$',fontsize=14) 
    elif i==7:
        plt.text(d,e1,r'$P(k)=0.05k^{-0.55}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.70$',fontsize=14) 
    elif i==8:
        plt.text(d,e1,r'$P(k)=0.05k^{-0.55}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.73$',fontsize=14) 
    elif i==9:
        plt.text(d,e1,r'$P(k)=0.04k^{-0.56}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.74$',fontsize=14) 
    elif i==10:
        plt.text(d,e1,r'$P(k)=0.05k^{-0.58}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.74$',fontsize=14)
    elif i==11:
        plt.text(d,e1,r'$P(k)=0.05k^{-0.60}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.80$',fontsize=14) 
    elif i==12:
        plt.text(d,e1,r'$P(k)=0.05k^{-0.60}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.80$',fontsize=14) 
    elif i==13:
        plt.text(d,e1,r'$P(k)=0.05k^{-0.61}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.81$',fontsize=14) 
    elif i==14:
        plt.text(d,e1,r'$P(k)=0.05k^{-0.61}$',fontsize=15)
        plt.text(d,e2,r'$R^2 \equal 0.80$',fontsize=14) 
    elif i==15:
        plt.text(d,e1,r'$P(k)=0.05k^{-0.60}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.77$',fontsize=14) 
    elif i==16:
        plt.text(d,e1,r'$P(k)=0.05k^{-0.60}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.78$',fontsize=14) 
    elif i==17:
        plt.text(d,e1,r'$P(k)=0.05k^{-0.61}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.78$',fontsize=14) 
    elif i==18:
        plt.text(d,e1,r'$P(k)=0.04k^{-0.61}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.79$',fontsize=14) 
    elif i==19:
        plt.text(d,e1,r'$P(k)=0.04k^{-0.61}$',fontsize=14)
        plt.text(d,e2,r'$R^2 \equal 0.77$',fontsize=14) 
    plt.legend(loc='upper right',bbox_to_anchor=(1, 1),fontsize=14)
    plt.grid()
    plt.rcParams['axes.facecolor'] = 'white'
    n+=1
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.28)
plt.savefig('D:Fig_S8/FigS8.TIFF',dpi=300,bbox_inches='tight')
plt.show()

# %%
#Fig.S9
fig = plt.figure(figsize=(20, 30))
n=1

for i in range(2,len(files)):
    time=files[i].replace('.csv','')
    print(time)
    position=file_path+files[i]
    df=pd.read_csv(position,encoding='gbk')
    
    ax1 = fig.add_subplot(6,3,n)
    ax1.set_title(time,fontsize=12)
    degree=list(df['degree'])
    d=degree[0:degree.index(0)]
    x, y = ccdf(d, linear_bins=True)
    ax1.scatter(x, y, color='g', s=8, label='degree data')
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15) 
    plt.title(time,fontsize=15)
    fit = Fit(d, discrete=True,xmin=min(d))
    print(fit.distribution_compare('power_law', 'lognormal'))

    fit.power_law.plot_ccdf(ax=ax1, color='#CD3F2C', linestyle='--', label='Power law fit')
    fit.lognormal.plot_ccdf(ax=ax1, color='#FF8FA2', linestyle='--', label='Lognormal fit')
    
    if n==1 or n==4 or n==7 or n==10 or n==13 or n==16:
        ax1.set_ylabel(u"p(K≥k)",fontsize=15)
    if n>15:
        ax1.set_xlabel("k",fontsize=15)
    
    handles, labels = ax1.get_legend_handles_labels()
    ax1.legend(handles, labels, loc=3,fontsize=15)
    
    print('alpha:',fit.power_law.alpha)
    print('sigma:',fit.power_law.sigma)
    print('D:',fit.power_law.D)
    n+=1
    print(n)
fig.savefig('D:data/paper_1/method_1/pnas_fig/FigS9.TIFF',dpi=300,bbox_inches='tight')
plt.show()
